# %%
import pandas as pd 
import yfinance as yf
from datetime import datetime as dt



def merge_df(df, data):

    df['date']= pd.to_datetime(df['date'], format='%Y-%m-%d', errors='ignore')

    data.reset_index(inplace=True)
    data=data.rename(columns= {'Date': 'date'})
    
    data['close'] = data['Close'].round(2) #rounding the price on close
    data = data[['date','close', 'daily_return', 'stock_return_percentage']]
    
     #Pull only the date and the close 
    df = df.merge(data, on='date') #merge data onto the df using date

    #df['Close'].loc[((df['date'] == 'C')] 
    return df



ticker = 'SPY'

df = pd.read_csv(f'../{ticker}nope_3.csv')
data = yf.download(ticker)

df['nope'] = df['nope']*100
df['gex'] = df['gex']*100
final_day=df.date.head(1).item()
final_day = dt.strptime(final_day, '%Y-%m-%d')

data = yf.download(ticker, start=final_day, end="2021-01-01")

stock_return = data['Close'] - data['Close'].shift()

data['daily_return'] = stock_return
stock_return_percentage = ((data['Close'] - data['Close'].shift())/data['Close'].shift())*100
data['stock_return_percentage'] = stock_return_percentage


df = merge_df(df, data)


df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/y2/h_8rlf9n4j7_n18fl85927fm0000gn/T/ipykernel_4629/2148644321.py in <module>
#      27 ticker = 'SPY'
#      28
# ---> 29 df = pd.read_csv(f'../{ticker}nope_3.csv')
#      30 data = yf.download(ticker)
#      31
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib
'''
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})'''
#df = df[['close', 'stock_return_percentage', 'nope', 'gex', 'call_iv_aggregate', 'put_iv_aggregate', 'call_open_interest_aggregate', 'put_open_interest_aggregate']] #matplotlib.pyplot


#nope_oi	gex_volume	net_vanna_oi	net_vanna_volume	net_zomma_oi	net_zomma_volume
#nope_oi_normalised	gex_volume_normalised	gex_normalised	net_vanna_oi_normalised	net_vanna_volume_normalised	net_zomma_oi_normalised	net_zomma_volume_normalised
#df.nope = df.nope.cumsum()
#plt.figure()
start_year = 2015
end_year = 2020
df_testing = df[f'{start_year}0101':f'{end_year}1230']

fig, ax1 = plt.subplots()
#df = df['20150101':'20201230']
color = 'tab:red'
ax1.set_xlabel('time')
ax1.set_ylabel('SPY', color=color)
ax1.plot(df_testing.close, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx() 

xnope = df_testing.nope
xnope = xnope.rolling(window=5).mean()
color = 'tab:blue'
plt.grid()
ax2.set_ylabel('NOPE', color=color)  
ax2.plot(xnope, color=color)
ax2.tick_params(axis='y', labelcolor=color)


fig.tight_layout()  
plt.show()
plt.grid()
plt.plot(df.net_vanna_oi)

# %%
fig, ax1 = plt.subplots()
#df = df['20150101':'20201230']
color = 'tab:red'
ax1.set_xlabel('time')
ax1.set_ylabel('SPY', color=color)
ax1.plot(df.stock_return_percentage, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx() 

color = 'tab:blue'
ax2.set_ylabel('GEX', color=color) 
ax2.plot(df.gex, color=color)
ax2.tick_params(axis='y', labelcolor=color)


fig.tight_layout() 
plt.show()

# %%
fig, ax1 = plt.subplots()

x1 = df.call_open_interest_aggregate
print(x1)
x1 = x1.rolling(window=5).mean()
#x1 = x1.expanding(min_periods=10).mean()
print(x1)
# plotting the line 1 points 
plt.plot(x1, label = "Open Interest Calls")
# line 2 points

x2 = df.put_open_interest_aggregate
x2 = x2.rolling(window=5).mean()


x3 =  df.put_open_interest_aggregate - df.call_open_interest_aggregate 
x3 = x3.rolling(window=5).mean()
# plotting the line 2 points 
plt.plot(x2, label = "Open Interest Puts")
plt.plot(x3, label = "Net Open interest")
plt.xlabel('Date')
# Set the y axis label of the current axis.
plt.ylabel('Date')
# Set a title of the current axes.
plt.title('Call and put open interest')
# show a legend on the plot
plt.legend()
plt.figure(figsize=(8, 20), dpi=80)

ax2 = ax1.twinx()
ax2.plot(df.close, color='red', label='SPY Close')
# Display a figure.
plt.show()

# %%
#box_list = ['nope', 'gex', 'nope_oi',	'gex_volume',	'net_vanna_oi',	'net_vanna_volume',	'net_zomma_oi',	'net_zomma_volume', 'nope_oi_normalised','gex_volume_normalised','gex_normalised', 'net_vanna_oi_normalised', 'net_vanna_volume_normalised',	'net_zomma_oi_normalised',	'net_zomma_volume_normalised']
box_list = ['nope', 'gex', 'nope_oi','net_vanna_oi','net_zomma_oi']
name_list = ['NOPE', 'GEX', 'NOPE OI Modified','Net Vanna','Net Zomma']
#name_list = ['NOPE', 'GEX', 'Nope OI Modifed',	'gex_volume',	'net_vanna_oi',	'net_vanna_volume',	'net_zomma_oi',	'net_zomma_volume', 'nope_oi_normalised','gex_volume_normalised','gex_normalised', 'net_vanna_oi_normalised', 'net_vanna_volume_normalised',	'net_zomma_oi_normalised',	'net_zomma_volume_normalised']
start_year = 2015
end_year = 2020
y_test =  df_new.stock_return_percentage.shift(periods=1)

j=0
for i in box_list:
    plt.xlabel(f'{name_list[j]}')
    plt.ylabel('Daily Return %')

    plt.title(f'SPY Next Day Returns vs {name_list[j]}, {start_year} - {end_year}')
    df_new = df[f'{start_year}0101':f'{end_year}1230']

    x_test = df_new[i]
    

    plt.scatter(x_test, y_test)
    plt.show()
    j=j+1

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

n_bins = 100


fig, axs = plt.subplots(1,1, sharey=True, tight_layout=True)
plt.title(f'SPY Daily Returns at Close {start_year} - {end_year}')
plt.xlabel('Daily Return at Close %')
plt.ylabel('Frequency')



axs.hist(df.stock_return_percentage, bins=n_bins, histtype ='bar',ec='black')
